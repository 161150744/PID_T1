# %%
from skimage import data, io, filters, exposure

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

# %%
horse2=io.imread('download (3).jpeg.jpeg')

# %%
horse=io.imread('download (2).jpeg')

# %%
io.imshow(horse[:,:,0])
# Out:
# /home/sa/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/sa/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
io.imshow(horse2[:,:,0])
# Out:
# /home/sa/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/sa/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
horse=horse[:,:,0]
io.imshow(horse)
horse
# Out:
# /home/sa/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/sa/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# array([[189, 189, 189, ..., 185, 185, 185],
#        [189, 189, 189, ..., 185, 185, 185],
#        [189, 189, 189, ..., 186, 186, 186],
#        ...,
#        [ 73,  69,  81, ..., 114, 119,  97],
#        [ 74,  60,  81, ...,  98,  87,  95],
#        [ 63,  66,  80, ..., 113,  82, 124]], dtype=uint8)

# %%
horse2=horse2[:,:,0]
io.imshow(horse2)
horse2
# Out:
# /home/sa/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/sa/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# array([[254, 254, 254, ..., 252, 252, 252],
#        [254, 254, 254, ..., 252, 252, 252],
#        [254, 254, 254, ..., 252, 252, 252],
#        ...,
#        [106,  83,  53, ..., 137, 150, 125],
#        [122,  39,  19, ..., 136, 142, 133],
#        [ 90,  90,  68, ..., 138, 134, 145]], dtype=uint8)

# %%
horse[:][0]
# Out:
# array([189, 189, 189, 189, 188, 186, 185, 185, 184, 184, 184, 183, 183,
#        183, 183, 183, 181, 181, 181, 181, 181, 180, 180, 180, 184, 182,
#        182, 183, 184, 184, 184, 185, 185, 185, 185, 184, 184, 184, 183,
#        183, 184, 184, 184, 184, 184, 184, 184, 184, 185, 185, 185, 184,
#        184, 183, 183, 183, 185, 185, 184, 182, 181, 180, 179, 179, 179,
#        179, 178, 177, 176, 174, 174, 173, 173, 172, 172, 171, 170, 170,
#        169, 169, 165, 165, 165, 164, 164, 164, 163, 163, 162, 162, 162,
#        162, 162, 162, 162, 162, 164, 164, 164, 165, 165, 165, 166, 166,
#        167, 167, 168, 168, 168, 169, 169, 169, 168, 168, 168, 168, 169,
#        169, 170, 170, 172, 172, 173, 173, 173, 174, 174, 174, 176, 176,
#        177, 177, 177, 177, 177, 176, 172, 172, 169, 169, 168, 168, 168,
#        167, 173, 176, 178, 175, 172, 166, 160, 156, 156, 148, 139, 129,
#        119, 108, 102,  98,  88,  88,  88,  87,  89,  88,  88,  88,  90,
#         95, 101, 108, 120, 135, 154, 167, 187, 185, 186, 190, 193, 188,
#        186, 184, 187, 188, 187, 184, 183, 181, 180, 179, 176, 176, 175,
#        174, 173, 173, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172,
#        177, 179, 181, 183, 185, 188, 190, 191, 191, 193, 194, 194, 196,
#        197, 198, 198, 199, 197, 194, 191, 190, 191, 193, 194, 189, 189,
#        189, 188, 187, 186, 186, 185, 183, 183, 183, 183, 183, 183, 183,
#        183, 183, 183, 183, 183, 183, 183, 183, 183, 180, 180, 181, 181,
#        181, 184, 184, 184, 183, 183, 183, 184, 184, 184, 184, 184, 185,
#        185, 185], dtype=uint8)

# %%
image=horse
# image = data.coins()
edges = filters.sobel(image)
plt.bar( exposure.histogram(image)[1], exposure.histogram(image)[0])
# Out:
# <BarContainer object of 256 artists>

# %%
io.imshow(image)
# Out:
# /home/sa/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/sa/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
image2 = horse2
edges = filters.sobel(image2)
plt.bar( exposure.histogram(image2)[1], exposure.histogram(image2)[0])
# Out:
# <BarContainer object of 256 artists>

# %%
io.imshow(image2)
# Out:
# /home/sa/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/sa/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
#classification
soma=0
for i in range(len(exposure.histogram(image2)[0])):
    soma+=min(exposure.histogram(image2)[0][i], exposure.histogram(image)[0][i])
soma2=0
for i in range(len(exposure.histogram(image)[0])):
    soma2+=exposure.histogram(image)[0][i]
soma/soma2
# Out:
# 0.49853949329359165
